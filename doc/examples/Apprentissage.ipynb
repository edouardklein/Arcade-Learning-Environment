# %%
    toto = genfromtxt('Apprentissage.mat')
    tata = genfromtxt('Appris.mat')
    plot(toto[:,0],toto[:,1])
    plot(range(1,121,10),tata)
    mean(toto[:,1]),mean(tata)
# Out:
# (262.38532110091745, 258.33333333333331)
